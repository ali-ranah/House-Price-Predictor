# %% [markdown]
# # Islamabad House Prices Prediction

# %%
import numpy as np
import pandas as pd

# %%
ism = pd.read_csv("data.csv")

# %%
ism.head(2)
# Out:
#    Unnamed: 0  property_id  location_id  \
# 0           0       237062         3325
# 1           1       346905         3236
#
#                                             page_url property_type     price  \
# 0  https://www.zameen.com/Property/g_10_g_10_2_gr...          Flat  10000000
# 1  https://www.zameen.com/Property/e_11_2_service...          Flat   6900000
#
#   location       city      province_name   latitude  longitude  baths  \
# 0     G-10  Islamabad  Islamabad Capital  33.679890  73.012640      2
# 1     E-11  Islamabad  Islamabad Capital  33.700993  72.971492      3
#
#     purpose  bedrooms date_added agency agent  Total_Area
# 0  For Sale         2   2/4/2019    NaN   NaN    1089.004
# 1  For Sale         3   5/4/2019    NaN   NaN   15246.056

# %% [markdown]
# Now we will extract Islamabad housing data

# %%
ism = ism[ism['city'] == 'Islamabad']

# %%
ism["purpose"].value_counts()
# Out:
# purpose
# For Rent    21320
# For Sale    16106
# Name: count, dtype: int64

# %%
ism = ism[ism['purpose'] == 'For Sale']

# %%
ism = ism[ism['property_type'] == 'House']

# %%
ism['price'] = ism['price'].apply(lambda x: x/100000)

# %%
ism['price']
# Out:
# 2         165.0
# 3         435.0
# 4          70.0
# 5         345.0
# 6         270.0
#           ...
# 168306    127.0
# 168307    270.0
# 168308     90.0
# 168309    140.0
# 168312      1.0
# Name: price, Length: 11908, dtype: float64

# %%
ism = ism[ism['price'] < 4000]

# %%
ism['price'].values
# Out:
# array([165., 435.,  70., ...,  90., 140.,   1.])

# %%
ism.head()
# Out:
#    Unnamed: 0  property_id  location_id  \
# 2           2       386513          764
# 3           3       656161          340
# 4           4       841645         3226
# 5           5       850762         3390
# 6           6       937975          445
#
#                                             page_url property_type  price  \
# 2  https://www.zameen.com/Property/islamabad_g_15...         House  165.0
# 3  https://www.zameen.com/Property/islamabad_bani...         House  435.0
# 4  https://www.zameen.com/Property/dha_valley_dha...         House   70.0
# 5  https://www.zameen.com/Property/ghauri_town_gh...         House  345.0
# 6  https://www.zameen.com/Property/islamabad_kora...         House  270.0
#
#       location       city      province_name   latitude  longitude  baths  \
# 2         G-15  Islamabad  Islamabad Capital  33.631486  72.926559      6
# 3    Bani Gala  Islamabad  Islamabad Capital  33.707573  73.151199      4
# ...

# %%
ism = ism.drop(ism.columns[[0]],axis = 1)

# %%
ism.head()
# Out:
#    property_id  location_id  \
# 2       386513          764
# 3       656161          340
# 4       841645         3226
# 5       850762         3390
# 6       937975          445
#
#                                             page_url property_type  price  \
# 2  https://www.zameen.com/Property/islamabad_g_15...         House  165.0
# 3  https://www.zameen.com/Property/islamabad_bani...         House  435.0
# 4  https://www.zameen.com/Property/dha_valley_dha...         House   70.0
# 5  https://www.zameen.com/Property/ghauri_town_gh...         House  345.0
# 6  https://www.zameen.com/Property/islamabad_kora...         House  270.0
#
#       location       city      province_name   latitude  longitude  baths  \
# 2         G-15  Islamabad  Islamabad Capital  33.631486  72.926559      6
# 3    Bani Gala  Islamabad  Islamabad Capital  33.707573  73.151199      4
# 4  DHA Defence  Islamabad  Islamabad Capital  33.492591  73.301339      3
# ...

# %%
ism = ism.drop(['property_id', 'property_type', 'location_id', 'page_url', 'city', 'latitude', 'province_name', 'longitude', 'purpose', 'date_added', 'agency', 'agent'], axis=1)
ism.head()
# Out:
#    price     location  baths  bedrooms  Total_Area
# 2  165.0         G-15      6         5    2178.008
# 3  435.0    Bani Gala      4         4   10890.000
# 4   70.0  DHA Defence      3         3    2178.008
# 5  345.0  Ghauri Town      8         8   87120.000
# 6  270.0  Korang Town      8         8    5445.000

# %%
print(pd.unique(ism['location']))
# Out:
# ['G-15' 'Bani Gala' 'DHA Defence' 'Ghauri Town' 'Korang Town' 'B-17'
#  'G-11' 'Bhara kahu' 'Garden Town' 'Koral Town' 'Soan Garden' 'F-6' 'F-7'
#  'I-16' 'E-7' 'Emaar Canyon Views' 'G-13' 'F-17' 'Bahria Town'
#  'PWD Housing Scheme' 'F-11' 'Kuri Road' 'Pakistan Town'
#  'Chatha Bakhtawar' 'E-11' 'F-10' 'F-8' 'I-8' 'Lehtarar Road' 'G-9' 'E-14'
#  'G-8' 'I-14' 'Tarlai' 'Simly Dam Road' 'I-9' 'Burma Town'
#  'National Police Foundation O-9' 'Naval Anchorage' 'Islamabad Highway'
#  'CBR Town' 'National Police Foundation' 'G-10' 'Jhang Syedan' 'D-17'
#  'Arsalan Town' 'Kashmir Highway' 'I-10' 'PWD Road' 'Pir Sohawa' 'Ali Pur'
#  'FECHS' 'Khanna Pul' 'Shaheen Town' 'Jhangi Syedan' 'Chak Shahzad' 'H-13'
#  'G-14' 'Shah Allah Ditta' 'Islamabad Expressway' 'Margalla Town' 'Tarnol'
#  'H-15' 'D-13' 'Meherban Colony' 'Zaraj Housing Scheme'
#  'Multi Residencia & Orchards' 'AGHOSH'
#  'PAEC Employees Cooperative Housing Society' 'Taramrri' 'E-18'
# ...

# %%
ism.to_csv('cleaned_ism.csv')

# %% [markdown]
# # Now it's time buld model

# %%
ism.head()
# Out:
#    price     location  baths  bedrooms  Total_Area
# 2  165.0         G-15      6         5    2178.008
# 3  435.0    Bani Gala      4         4   10890.000
# 4   70.0  DHA Defence      3         3    2178.008
# 5  345.0  Ghauri Town      8         8   87120.000
# 6  270.0  Korang Town      8         8    5445.000

# %%
ism.shape
# Out:
# (11870, 5)

# %%
ism.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11870 entries, 2 to 168312
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   price       11870 non-null  float64
#  1   location    11870 non-null  object
#  2   baths       11870 non-null  int64
#  3   bedrooms    11870 non-null  int64
#  4   Total_Area  11870 non-null  float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 814.4+ KB

# %%
ism.describe()
# Out:
#               price         baths      bedrooms    Total_Area
# count  11870.000000  11870.000000  11870.000000  1.187000e+04
# mean     353.800546      4.012890      4.222157  4.214460e+04
# std      441.489680      2.676841      2.324489  3.109849e+06
# min        0.000010      0.000000      0.000000  0.000000e+00
# 25%      120.000000      2.000000      3.000000  1.633506e+03
# 50%      200.000000      4.000000      4.000000  2.722510e+03
# 75%      425.000000      6.000000      6.000000  1.089000e+04
# max     3900.000000     14.000000     16.000000  3.387988e+08

# %%
ism['location'] = ism['location'].apply(lambda x: x.strip())
location_count = ism['location'].value_counts()

# %%
location_count_less_10 = location_count[location_count <= 10]

# %%
ism['location'] = ism['location'].apply(lambda x: 'other' if x in location_count_less_10 else x)

# %%
ism['location'].value_counts()
# Out:
# location
# DHA Defence                      1420
# G-13                              942
# Bahria Town                       841
# Ghauri Town                       601
# I-8                               506
#                                  ...
# Shah Allah Ditta                   12
# Koral Town                         11
# Garden Town                        11
# Islamabad - Murree Expressway      11
# C-18                               11
# Name: count, Length: 82, dtype: int64

# %%
ism.head()
# Out:
#    price     location  baths  bedrooms  Total_Area
# 2  165.0         G-15      6         5    2178.008
# 3  435.0    Bani Gala      4         4   10890.000
# 4   70.0  DHA Defence      3         3    2178.008
# 5  345.0  Ghauri Town      8         8   87120.000
# 6  270.0  Korang Town      8         8    5445.000

# %% [markdown]
# # Train Test Split and  Model

# %%
X = ism.drop(columns=["price"])
y = ism["price"]

# %%
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import OneHotEncoder, StandardScaler

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %%
X_train.head()
# Out:
#                     location  baths  bedrooms  Total_Area
# 160895                   I-8      0         5   65340.000
# 101074             Bani Gala      5         5    2722.510
# 33136           Jhang Syedan      3         3    1361.255
# 80606   Zaraj Housing Scheme      5         4    3267.012
# 28103                   B-17      7         5    2178.008

# %%
y_train.head()
# Out:
# 160895    750.0
# 101074    105.0
# 33136      42.0
# 80606     190.0
# 28103     130.0
# Name: price, dtype: float64

# %%
column_trans = make_column_transformer((OneHotEncoder(sparse=False), ['location']),
                                       remainder='passthrough')

# %% [markdown]
# # Applying LinearRegression

# %%
scalar = StandardScaler()

# %%
lr = LinearRegression()
pipe = make_pipeline(column_trans,scalar,lr)
pipe.fit(X_train,y_train)
y_pred_lr = pipe.predict(X_test)
r2_score(y_test,y_pred_lr)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# 0.6995111266637125

# %% [markdown]
# # Applying Ridge

# %%
rid = Ridge()
pipe = make_pipeline(column_trans,scalar,rid)
pipe.fit(X_train,y_train)
y_pred_rid = pipe.predict(X_test)
r2_score(y_test,y_pred_rid)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# 0.6995102780244441

# %% [markdown]
# # Applying Lasso

# %%
rid = Lasso()
pipe = make_pipeline(column_trans,scalar,rid)
pipe.fit(X_train,y_train)
y_pred_lasso = pipe.predict(X_test)
r2_score(y_test,y_pred_lasso)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# 0.6990893108617175

# %%
import pickle
pickle.dump(pipe, open('model1.pkl','wb'))

# %%
model = RandomForestRegressor(max_depth=13, random_state=0)
pipe2 = make_pipeline(column_trans,scalar,model)
pipe2.fit(X_train,y_train)
y_pred_model = pipe2.predict(X_test)
r2_score(y_test,y_pred_model)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# 0.8618490640618919

# %%
pickle.dump(pipe2, open('model.pkl','wb'))

# %%
import pickle
import pandas as pd

# Load the model from the file
with open('model.pkl', 'rb') as f:
    model = pickle.load(f)

# Define a function to predict the price
def predict_price(location, bedrooms, bathrooms, size):
    input_data = pd.DataFrame({'location': [location], 'bedrooms': [bedrooms], 'baths': [bathrooms], 'Total_Area': [size]})
    predicted_price = model.predict(input_data)
    return predicted_price[0]

# Example usage:
location = 'Bani Gala'
bedrooms = 6
bathrooms = 5
size = 2178
predicted_price = predict_price(location, bedrooms, bathrooms, size)
print(f'Predicted price: {predicted_price*100000}')
# Out:
# Predicted price: 16130144.428747553
